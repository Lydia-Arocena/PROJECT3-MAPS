# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
import pyjsonviewer
from functools import reduce
import operator
import json
from pymongo import MongoClient
from pymongo import GEOSPHERE
from cartoframes.viz import Map, Layer, popup_element
import geopandas as gpd
import sys
sys.path.append('../')
import src.functions as func

# %% [markdown]
# ### Choosing 3 cities to place my office:

# %% [markdown]
# #### A. Madrid:

# %%
madrid=func.geocode("Castellana 89, Paseo de la Castellana, Madrid") #Torre Picasso.

# %%
madrid
# Out:
# {'type': 'Point', 'coordinates': ['40.44980', '-3.69164']}

# %% [markdown]
# #### B. Málaga:

# %%
malaga=func.geocode("Calle Larios, Malaga")

# %%
malaga
# Out:
# {'type': 'Point', 'coordinates': ['36.72048', '-4.42166']}

# %% [markdown]
# #### C. Barcelona:

# %%
barcelona=func.geocode("Plaça de Catalunya, Barcelona")

# %%
barcelona
# Out:
# {'type': 'Point', 'coordinates': ['41.38781', '2.16920']}

# %% [markdown]
# ### Prioritizing some requirements over othes:

# %% [markdown]
# - **Designers like to go to design talks and share knowledge. There must be some nearby companies that also do design.**
# - 30% of the company staff have at least 1 child.
# - Developers like to be near successful tech startups that have raised at least 1 Million dollars.
# - **Executives like Starbucks A LOT. Ensure there's a starbucks not too far.**
# - **Account managers need to travel a lot.**
# - **Everyone in the company is between 25 and 40, give them some place to go party.**
# - **The CEO is vegan.**
# - If you want to make the maintenance guy happy, a basketball stadium must be around 10 Km.
# - The office dog—"Dobby" needs a hairdresser every month. Ensure there's one not too far away.

# %% [markdown]
# ### API Foursquare requests:

# %%
load_dotenv()
# Out:
# True

# %%
client_id = os.getenv("tok1")
client_secret = os.getenv("tok2")

# %%
url = "https://favqs.com/api/session"
url_query = 'https://api.foursquare.com/v2/venues/search'

# %% [markdown]
# #### A. Madrid-Empresas de diseño:

# %%
parametros = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": "empresas de diseño"
}

# %%
dis_mad = requests.get(url_query, params = parametros).json()

# %%
#dis_mad

# %%
diseños_md = dis_mad["response"]["venues"]

# %%
#diseños_md

# %%
lista_diseñomad=func.extraetodo(diseños_md)

# %%
datos_diseñomadrid = pd.DataFrame(lista_diseñomad)

# %%
datos_diseñomadrid.head()
# Out:
#                                               nombre    latitud  longitud  \
# 0  Esne (Escuela Universitaria de Diseño, Innovac...  40.457096 -3.667365
# 1                Schmidt Hernani - Cocinas De Diseño  40.448264 -3.697171
# 2     Centro De Empresas De Seguridad Alonso Cano 99  40.445357 -3.697281
# 3                          Central de Diseño / DIMAD  40.392015 -3.696827
# 4                     empresas de piscinas en madrid  40.414419 -3.703423
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [40.457095782...
# 1  {'type': 'Point', 'coordinates': [40.448264292...
# 2  {'type': 'Point', 'coordinates': [40.445357283...
# 3  {'type': 'Point', 'coordinates': [40.392015380...
# 4  {'type': 'Point', 'coordinates': [40.414419115...

# %%
diseñoMadrid = datos_diseñomadrid.copy()

# %% [markdown]
# #### A. Madrid-Starbucks:

# %%
parametros_St = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": "Starbucks"
}

# %%
St_mad = requests.get(url_query, params = parametros_St).json()

# %%
#St_mad

# %%
St_datamd = St_mad["response"]["venues"]

# %%
lista_starbucksmad=func.extraetodo(St_datamd)

# %%
datos_Starbucksmadrid=pd.DataFrame(lista_starbucksmad)

# %%
datos_Starbucksmadrid.head()
# Out:
#       nombre    latitud  longitud  \
# 0  Starbucks  40.447489 -3.693093
# 1  Starbucks  40.447729 -3.695175
# 2  Starbucks  40.455046 -3.693885
# 3  Starbucks  40.432968 -3.683220
# 4  Starbucks  40.433564 -3.686829
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [40.447488723...
# 1  {'type': 'Point', 'coordinates': [40.447728697...
# 2  {'type': 'Point', 'coordinates': [40.455046, -...
# 3  {'type': 'Point', 'coordinates': [40.432967606...
# 4  {'type': 'Point', 'coordinates': [40.433563917...

# %%
StarbucksMadrid = datos_Starbucksmadrid.copy()

# %% [markdown]
# #### A. Madrid-Airports:

# %%
parametros_A = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": "Airport"
}

# %%
airport_mad=requests.get(url_query, params=parametros_A).json()

# %%
#airport_mad

# %%
air_datamd = airport_mad["response"]["venues"]

# %%
lista_airportmad=func.extraetodo(air_datamd)

# %%
datos_airportmadrid=pd.DataFrame(lista_airportmad)

# %%
datos_airportmadrid.head()
# Out:
#                                               nombre    latitud  longitud  \
# 0                                     AIRPORT TAVERN  40.454018 -3.678821
# 1                    Hotel NH Madrid Barajas Airport  40.451022 -3.594986
# 2                         Tryp Madrid Airport Suites  40.445569 -3.543607
# 3                  Saludando – Hilton Madrid Airport  40.452070 -3.585533
# 4  Aeropuerto Adolfo Suárez Madrid-Barajas (MAD) ...  40.490222 -3.569434
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [40.454017958...
# 1  {'type': 'Point', 'coordinates': [40.451022341...
# 2  {'type': 'Point', 'coordinates': [40.4455692, ...
# 3  {'type': 'Point', 'coordinates': [40.452070242...
# 4  {'type': 'Point', 'coordinates': [40.490222162...

# %% [markdown]
# #### A. Madrid-Disco:

# %%
parametros_D = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": "Disco"
}

# %%
disco_mad=requests.get(url_query,params=parametros_D).json()

# %%
disco_datamad=disco_mad["response"]["venues"]

# %%
lista_discomad=func.extraetodo(disco_datamad)

# %%
datos_discomadrid=pd.DataFrame(lista_discomad)

# %%
datos_discomadrid.head()
# Out:
#                 nombre    latitud  longitud  \
# 0     Disco Rug & Play  40.451888 -3.696266
# 1   Panamericana Disco  40.452806 -3.690264
# 2        Disco Express  40.434539 -3.710257
# 3      Disco Yedra Pub  40.434041 -3.714618
# 4  Destellos Pub Disco  40.437682 -3.709905
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [40.451888, -...
# 1  {'type': 'Point', 'coordinates': [40.452806048...
# 2  {'type': 'Point', 'coordinates': [40.434538914...
# 3  {'type': 'Point', 'coordinates': [40.434040912...
# 4  {'type': 'Point', 'coordinates': [40.437681716...

# %% [markdown]
# ####  A. Madrid-Vegan:

# %%
parametros_V= {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": "Vegan"
}

# %%
vegan_mad=requests.get(url_query,params=parametros_V).json()

# %%
vegan_datamad=vegan_mad["response"]["venues"]

# %%
lista_veganmad=func.extraetodo(vegan_datamad)

# %%
datos_veganmadrid=pd.DataFrame(lista_veganmad)

# %%
datos_veganmadrid.head()
# Out:
#                             nombre    latitud  longitud  \
# 0  Vegan Streets Madrid Castellana  40.442456 -3.679973
# 1      Vegan Streets Madrid Centro  40.417512 -3.697636
# 2    vegetarian / vegan restaurant  40.432974 -3.686693
# 3                Los Andenes Vegan  40.435206 -3.710348
# 4                    Mad Mad Vegan  40.424183 -3.700731
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [40.4424564, ...
# 1  {'type': 'Point', 'coordinates': [40.4175117, ...
# 2  {'type': 'Point', 'coordinates': [40.432974, -...
# 3  {'type': 'Point', 'coordinates': [40.435206, -...
# 4  {'type': 'Point', 'coordinates': [40.424183, -...

# %% [markdown]
# #### Suming up all requirements in a single list (Madrid).

# %%
MADRID=func.sum_requirements(lista_diseñomad, lista_starbucksmad, lista_airportmad, lista_discomad, lista_veganmad)

# %%
datos_MADRID=pd.DataFrame(MADRID)

# %%
datos_MADRID.sample()
# Out:
#            nombre    latitud  longitud  \
# 92  Disco Express  40.434539 -3.710257
#
#                                              location
# 92  {'type': 'Point', 'coordinates': [40.434538914...

# %% [markdown]
# #### B. Málaga-Empresas de diseño:

# %%
parametros_mlg = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{malaga['coordinates'][0]}, {malaga['coordinates'][1]}",
    "query": "empresas de diseño"
}

# %%
dis_mlg=requests.get(url_query,params=parametros_mlg).json()

# %%
#mlg_dis

# %%
diseños_mlg = dis_mlg["response"]["venues"]

# %%
lista_diseñomlg=func.extraetodo(diseños_mlg)

# %% [markdown]
# #### B. Málaga-Aeropuerto:

# %%
parametros_mlg_air = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{malaga['coordinates'][0]}, {malaga['coordinates'][1]}",
    "query": "airport"
}

# %%
air_mlg=requests.get(url_query,params=parametros_mlg_air).json()

# %%
airport_mlg = air_mlg["response"]["venues"]

# %%
lista_airportmlg=func.extraetodo(airport_mlg)

# %% [markdown]
# #### B. Málaga-Starbucks:

# %%
parametros_mlg_st = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{malaga['coordinates'][0]}, {malaga['coordinates'][1]}",
    "query": "Starbucks"
}

# %%
st_mlg=requests.get(url_query,params=parametros_mlg_st).json()

# %%
Starbucks_mlg = st_mlg["response"]["venues"]

# %%
lista_Starbucks_mlg=func.extraetodo(Starbucks_mlg)

# %% [markdown]
# #### B. Málaga-Disco:

# %%
parametros_mlg_disco = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{malaga['coordinates'][0]}, {malaga['coordinates'][1]}",
    "query": "disco"
}

# %%
disco_mlg=requests.get(url_query,params=parametros_mlg_disco).json()

# %%
disco_mlg = disco_mlg["response"]["venues"]

# %%
lista_disco_mlg=func.extraetodo(disco_mlg)

# %% [markdown]
# #### B. Málaga-Vegan:

# %%
parametros_mlg_vegan = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{malaga['coordinates'][0]}, {malaga['coordinates'][1]}",
    "query": "Vegan"
}

# %%
vegan_mlg=requests.get(url_query,params=parametros_mlg_vegan).json()

# %%
vegan_mlg = vegan_mlg["response"]["venues"]

# %%
lista_vegan_mlg=func.extraetodo(vegan_mlg)

# %% [markdown]
# #### Suming up all requirements in a single list (Málaga).

# %%
MALAGA=func.sum_requirements(lista_diseñomlg, lista_Starbucks_mlg, lista_airportmlg, lista_disco_mlg, lista_vegan_mlg)

# %%
datos_MALAGA=pd.DataFrame(MALAGA)

# %%
datos_MALAGA.sample(8)
# Out:
#                                     nombre    latitud  longitud  \
# 102                              La Vegana  36.724179 -4.418461
# 101                               Veganbnb  36.724776 -4.416009
# 19   Asesoría de Empresas Afyne A. Navarro  37.094494 -4.382405
# 57                                Gate B16  36.673277 -4.490313
# 107                   Himalaya Salon Vegan  36.740310 -4.091342
# 67                            Disco Bronco  36.714944 -4.424100
# 15        Centro de Incubación de Empresas  36.739432 -4.554170
# 23                               Starbucks  36.676346 -4.491327
#
#                                               location
# 102  {'type': 'Point', 'coordinates': [36.724179, -...
# 101  {'type': 'Point', 'coordinates': [36.724776, -...
# 19   {'type': 'Point', 'coordinates': [37.094494108...
# 57   {'type': 'Point', 'coordinates': [36.673276656...
# 107  {'type': 'Point', 'coordinates': [36.74031, -4...
# 67   {'type': 'Point', 'coordinates': [36.714944211...
# 15   {'type': 'Point', 'coordinates': [36.739431615...
# 23   {'type': 'Point', 'coordinates': [36.676345929...

# %% [markdown]
# #### C. Barcelona-Design:

# %%
parametros_bcn_dis = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{barcelona['coordinates'][0]}, {barcelona['coordinates'][1]}",
    "query": "Diseño"
}

# %%
dis_bcn=requests.get(url_query,params=parametros_bcn_dis).json()

diseño_bcn = dis_bcn["response"]["venues"]

lista_diseñobcn=func.extraetodo(diseño_bcn)

# %% [markdown]
# #### C. Barcelona-Airport:

# %%
parametros_bcn_air = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{barcelona['coordinates'][0]}, {barcelona['coordinates'][1]}",
    "query": "Airport"
}

# %%
air_bcn=requests.get(url_query,params=parametros_bcn_air).json()

airport_bcn = air_bcn["response"]["venues"]

lista_airportbcn=func.extraetodo(airport_bcn)

# %% [markdown]
# #### C. Barcelona-Starbucks:

# %%
parametros_bcn_st = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{barcelona['coordinates'][0]}, {barcelona['coordinates'][1]}",
    "query": "Starbucks"
}

# %%
st_bcn=requests.get(url_query,params=parametros_bcn_st).json()

starbucks_bcn = st_bcn["response"]["venues"]

lista_starbucksbcn=func.extraetodo(starbucks_bcn)

# %% [markdown]
# #### C. Barcelona-Disco:

# %%
parametros_bcn_disco = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{barcelona['coordinates'][0]}, {barcelona['coordinates'][1]}",
    "query": "Disco"
}

# %%
disco_bcn=requests.get(url_query,params=parametros_bcn_disco).json()

discoteca_bcn = disco_bcn["response"]["venues"]

lista_discotecabcn=func.extraetodo(discoteca_bcn)

# %% [markdown]
# #### C. Barcelona-Vegan:

# %%
parametros_bcn_veg = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{barcelona['coordinates'][0]}, {barcelona['coordinates'][1]}",
    "query": "Vegan"
}

# %%
veg_bcn=requests.get(url_query,params=parametros_bcn_veg).json()

vegan_bcn = veg_bcn["response"]["venues"]

lista_veganbcn=func.extraetodo(vegan_bcn)

# %% [markdown]
# #### Suming up all requirements in a single list (Barcelona).

# %%
BARCELONA=func.sum_requirements(lista_diseñobcn, lista_airportbcn, lista_starbucksbcn, lista_discotecabcn, lista_veganbcn)

# %%
datos_BARCELONA=pd.DataFrame(BARCELONA)

# %%
datos_BARCELONA.sample(10)
# Out:
#                               nombre    latitud  longitud  \
# 15                      dulce diseño  41.402268  2.158632
# 9                       Dulce Diseño  41.359226  2.129343
# 23            Estudio de Diseño OEOE  41.387651  2.144509
# 44    Shuttle Tryp Hotel-Bcn Airport  41.312460  2.068220
# 140                       EnjoyVegan  41.388145  2.180385
# 35         hotel airport shuttle bus  41.352193  2.126967
# 34   Taxi richting Barcelona airport  41.376675  2.174543
# 6               Dulce Diseño El Born  41.388119  2.178501
# 37                The Airport Market  41.288707  2.073026
# 122               Cuco Vegan Fashion  41.382320  2.173978
#
#                                               location
# 15   {'type': 'Point', 'coordinates': [41.402268, 2...
# 9    {'type': 'Point', 'coordinates': [41.359225903...
# 23   {'type': 'Point', 'coordinates': [41.387651, 2...
# 44   {'type': 'Point', 'coordinates': [41.31246, 2....
# 140  {'type': 'Point', 'coordinates': [41.388144812...
# 35   {'type': 'Point', 'coordinates': [41.352193, 2...
# 34   {'type': 'Point', 'coordinates': [41.376675, 2...
# 6    {'type': 'Point', 'coordinates': [41.388118801...
# 37   {'type': 'Point', 'coordinates': [41.288706641...
# 122  {'type': 'Point', 'coordinates': [41.38232, 2....

# %% [markdown]
# ### Exporting data to Mongo DB Compass.

# %% [markdown]
# #### A. Madrid:

# %%
with open ("Madrid.json","w") as f: 
    json.dump(MADRID,f)

# %% [markdown]
# #### B. Málaga:

# %%
with open ("Malaga.json","w") as f: 
    json.dump(MALAGA,f)

# %% [markdown]
# #### C. Barcelona:

# %%
with open ("Barcelona.json","w") as f: 
    json.dump(BARCELONA,f)

# %% [markdown]
# ### Geoqueries:

# %%
client = MongoClient("localhost:27017")
db = client.get_database("PROYECTO_3")  # Me conecto a la base de datos "PROYECTO_3"
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'PROYECTO_3')

# %% [markdown]
# #### A. Madrid:

# %%
Madrid = db.get_collection("MADRID") # Me conecto a la colección "MADRID".

# %%
Madrid
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'PROYECTO_3'), 'MADRID')

# %%
db.Madrid.create_index([("location", GEOSPHERE)]) # Creo el index 2dsphere.
# Out:
# 'location_2dsphere'

# %%
madrid # mi posición en Madrid: Torre Picasso.
# Out:
# {'type': 'Point', 'coordinates': ['40.44980', '-3.69164']}

# %%
madrid_longlat=[-3.69164,40.44980]

# %%
madrid_alreves=func.type_point(madrid_longlat)

# %%
metros= 2000 # radio máximo de búsqueda que establezco respecto a mis coordenadas.

# %%
query = {"location": {"$near": {"$geometry":{'type': 'Point', 'coordinates': [40.44980, -3.69164]}, "$maxDistance": metros}}}

# %%
query
# Out:
# {'location': {'$near': {'$geometry': {'type': 'Point',
#     'coordinates': [40.4498, -3.69164]},
#    '$maxDistance': 2000}}}

# %%
list(Madrid.find(query))
# Out:
# [{'_id': ObjectId('618fc444e231d949cbb2dda2'),
#   'nombre': 'Starbucks',
#   'latitud': 40.44748872381242,
#   'longitud': -3.6930934929855574,
#   'location': {'type': 'Point',
#    'coordinates': [40.44748872381242, -3.6930934929855574]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dddf'),
#   'nombre': 'Panamericana Disco',
#   'latitud': 40.45280604818057,
#   'longitud': -3.69026365205175,
#   'location': {'type': 'Point',
#    'coordinates': [40.45280604818057, -3.69026365205175]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dded'),
#   'nombre': 'la cubana discoteca',
#   'latitud': 40.450147,
#   'longitud': -3.695196,
#   'location': {'type': 'Point', 'coordinates': [40.450147, -3.695196]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dda3'),
#   'nombre': 'Starbucks',
#   'latitud': 40.44772869759542,
#   'longitud': -3.6951754717412046,
#   'location': {'type': 'Point',
#    'coordinates': [40.44772869759542, -3.6951754717412046]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddde'),
#   'nombre': 'Disco Rug & Play',
#   'latitud': 40.451888,
#   'longitud': -3.696266,
#   'location': {'type': 'Point', 'coordinates': [40.451888, -3.696266]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dda4'),
#   'nombre': 'Starbucks',
#   'latitud': 40.455046,
#   'longitud': -3.693885,
#   'location': {'type': 'Point', 'coordinates': [40.455046, -3.693885]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd85'),
#   'nombre': 'Schmidt Hernani - Cocinas De Diseño',
#   'latitud': 40.448264292158974,
#   'longitud': -3.6971709936186516,
#   'location': {'type': 'Point',
#    'coordinates': [40.448264292158974, -3.6971709936186516]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd86'),
#   'nombre': 'Centro De Empresas De Seguridad Alonso Cano 99',
#   'latitud': 40.445357283,
#   'longitud': -3.697281176,
#   'location': {'type': 'Point', 'coordinates': [40.445357283, -3.697281176]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd89'),
#   'nombre': 'Carrera De Las Empresas',
#   'latitud': 40.442509,
#   'longitud': -3.69483,
#   'location': {'type': 'Point', 'coordinates': [40.442509, -3.69483]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd8f'),
#   'nombre': 'Julio Jimenez estudio de Arquitectura y diseño',
#   'latitud': 40.44026798739194,
#   'longitud': -3.6955904960632324,
#   'location': {'type': 'Point',
#    'coordinates': [40.44026798739194, -3.6955904960632324]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddb5'),
#   'nombre': 'Starbucks',
#   'latitud': 40.459101,
#   'longitud': -3.685668,
#   'location': {'type': 'Point', 'coordinates': [40.459101, -3.685668]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddee'),
#   'nombre': 'discoteca sueño latino',
#   'latitud': 40.45590105398211,
#   'longitud': -3.701138648753884,
#   'location': {'type': 'Point',
#    'coordinates': [40.45590105398211, -3.701138648753884]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddf1'),
#   'nombre': 'Discoteca Sueños',
#   'latitud': 40.457673665790686,
#   'longitud': -3.7012377483088637,
#   'location': {'type': 'Point',
#    'coordinates': [40.457673665790686, -3.7012377483088637]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd90'),
#   'nombre': 'Impoconta asesoría de empresas',
#   'latitud': 40.462532611,
#   'longitud': -3.69161293,
#   'location': {'type': 'Point', 'coordinates': [40.462532611, -3.69161293]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd91'),
#   'nombre': 'Consultores de Proyectos y Diseño',
#   'latitud': 40.440735473843766,
#   'longitud': -3.6818377569778895,
#   'location': {'type': 'Point',
#    'coordinates': [40.440735473843766, -3.6818377569778895]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dda8'),
#   'nombre': 'Starbucks',
#   'latitud': 40.440273,
#   'longitud': -3.682125,
#   'location': {'type': 'Point', 'coordinates': [40.440273, -3.682125]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddc0'),
#   'nombre': 'AIRPORT TAVERN',
#   'latitud': 40.45401795837524,
#   'longitud': -3.678820633312091,
#   'location': {'type': 'Point',
#    'coordinates': [40.45401795837524, -3.678820633312091]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddfc'),
#   'nombre': 'Vegan Streets Madrid Castellana',
#   'latitud': 40.4424564,
#   'longitud': -3.679973,
#   'location': {'type': 'Point', 'coordinates': [40.4424564, -3.679973]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddef'),
#   'nombre': 'Discoteca Nells Madrid',
#   'latitud': 40.439664,
#   'longitud': -3.682127,
#   'location': {'type': 'Point', 'coordinates': [40.439664, -3.682127]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddf5'),
#   'nombre': 'Discovery Formación',
#   'latitud': 40.458481,
#   'longitud': -3.680256,
#   'location': {'type': 'Point', 'coordinates': [40.458481, -3.680256]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd93'),
#   'nombre': 'Unidad de Grandes Empresas',
#   'latitud': 40.464108818323915,
#   'longitud': -3.6942913395154875,
#   'location': {'type': 'Point',
#    'coordinates': [40.464108818323915, -3.6942913395154875]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddf0'),
#   'nombre': 'Discoteca BAO-BAB Madrid',
#   'latitud': 40.453919368184145,
#   'longitud': -3.6776626110076904,
#   'location': {'type': 'Point',
#    'coordinates': [40.453919368184145, -3.6776626110076904]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dd8a'),
#   'nombre': 'Reformas de Diseño',
#   'latitud': 40.43675671753991,
#   'longitud': -3.6983799934387207,
#   'location': {'type': 'Point',
#    'coordinates': [40.43675671753991, -3.6983799934387207]}},
#  {'_id': ObjectId('618fc444e231d949cbb2dda6'),
#   'nombre': 'Starbucks',
#   'latitud': 40.4335639178076,
#   'longitud': -3.6868293595360973,
#   'location': {'type': 'Point',
#    'coordinates': [40.4335639178076, -3.6868293595360973]}},
#  {'_id': ObjectId('618fc444e231d949cbb2ddfe'),
#   'nombre': 'vegetarian / vegan restaurant',
#   'latitud': 40.432974,
#   'longitud': -3.686693,
#   'location': {'type': 'Point', 'coordinates': [40.432974, -3.686693]}}]

# %%
datos_MADRID.sample()
# Out:
#                 nombre    latitud  longitud  \
# 91  Panamericana Disco  40.452806 -3.690264
#
#                                              location  \
# 91  {'type': 'Point', 'coordinates': [40.452806048...
#
#                      geometry
# 91  POINT (-3.69026 40.45281)

# %%
type(datos_MADRID)
# Out:
# pandas.core.frame.DataFrame

# %%
gdf = gpd.GeoDataFrame(datos_MADRID, geometry=gpd.points_from_xy(datos_MADRID.longitud, datos_MADRID.latitud))

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf.sample()
# Out:
#        nombre   latitud  longitud  \
# 46  Starbucks  40.42332 -3.710883
#
#                                              location  \
# 46  {'type': 'Point', 'coordinates': [40.423319643...
#
#                      geometry
# 46  POINT (-3.71088 40.42332)

# %%
Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "Sitios cerca de mi propuesta de ubicación en Madrid")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %% [markdown]
# #### B. Málaga:

# %%
client = MongoClient("localhost:27017")
db = client.get_database("PROYECTO_3")  # Me conecto a la base de datos "PROYECTO_3"
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'PROYECTO_3')

# %%
MALAGA = db.get_collection("MALAGA") # Me conecto a la colección "MALAGA".

# %% [markdown]
# MALAGA

# %%
db.MALAGA.create_index([("location", GEOSPHERE)]) # Creo el index 2dsphere.
# Out:
# 'location_2dsphere'

# %%
metros= 2000 # radio máximo de búsqueda que establezco respecto a mis coordenadas.

# %%
query = {"location": {"$near": {"$geometry":{'type': 'Point', 'coordinates': [36.72048, -4.42166]}, "$maxDistance": metros}}}

# %%
query
# Out:
# {'location': {'$near': {'$geometry': {'type': 'Point',
#     'coordinates': [36.72048, -4.42166]},
#    '$maxDistance': 2000}}}

# %%
list(MALAGA.find(query))
# Out:
# [{'_id': ObjectId('619017ebe231d949cbb2de67'),
#   'nombre': 'Discos Candilejas',
#   'latitud': 36.72188758850098,
#   'longitud': -4.4217449426651,
#   'location': {'type': 'Point',
#    'coordinates': [36.72188758850098, -4.4217449426651]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de36'),
#   'nombre': 'Starbucks Félix Saenz',
#   'latitud': 36.719120753900825,
#   'longitud': -4.423157707352322,
#   'location': {'type': 'Point',
#    'coordinates': [36.719120753900825, -4.423157707352322]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de6b'),
#   'nombre': 'City Locker / Discoveringmalaga',
#   'latitud': 36.719645,
#   'longitud': -4.423855,
#   'location': {'type': 'Point', 'coordinates': [36.719645, -4.423855]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de85'),
#   'nombre': 'Veganized - non toxic fashion',
#   'latitud': 36.720366,
#   'longitud': -4.424072,
#   'location': {'type': 'Point', 'coordinates': [36.720366, -4.424072]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de6a'),
#   'nombre': 'Discoteca Andén',
#   'latitud': 36.72260692286189,
#   'longitud': -4.420381324170116,
#   'location': {'type': 'Point',
#    'coordinates': [36.72260692286189, -4.420381324170116]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de23'),
#   'nombre': 'Tango Estudio de diseño',
#   'latitud': 36.72118788261539,
#   'longitud': -4.424590766429901,
#   'location': {'type': 'Point',
#    'coordinates': [36.72118788261539, -4.424590766429901]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de88'),
#   'nombre': 'La Vegana',
#   'latitud': 36.724179,
#   'longitud': -4.418461,
#   'location': {'type': 'Point', 'coordinates': [36.724179, -4.418461]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de24'),
#   'nombre': 'Medio Melón Estudio de Diseño Gráfico',
#   'latitud': 36.72384085898497,
#   'longitud': -4.418048858642578,
#   'location': {'type': 'Point',
#    'coordinates': [36.72384085898497, -4.418048858642578]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de83'),
#   'nombre': 'Mimo Vegan Bistro',
#   'latitud': 36.716062,
#   'longitud': -4.424227,
#   'location': {'type': 'Point', 'coordinates': [36.716062, -4.424227]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de25'),
#   'nombre': 'Gestem Planificacion Y Desarrollo Integral De Empresas',
#   'latitud': 36.715145,
#   'longitud': -4.421811,
#   'location': {'type': 'Point', 'coordinates': [36.715145, -4.421811]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de65'),
#   'nombre': 'Disco Bronco',
#   'latitud': 36.71494421198828,
#   'longitud': -4.424099922180176,
#   'location': {'type': 'Point',
#    'coordinates': [36.71494421198828, -4.424099922180176]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de87'),
#   'nombre': 'Veganbnb',
#   'latitud': 36.724776,
#   'longitud': -4.416009,
#   'location': {'type': 'Point', 'coordinates': [36.724776, -4.416009]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de37'),
#   'nombre': 'Starbucks ECI Málaga Hilera',
#   'latitud': 36.71807037393208,
#   'longitud': -4.429668877296518,
#   'location': {'type': 'Point',
#    'coordinates': [36.71807037393208, -4.429668877296518]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de84'),
#   'nombre': 'Vegan La Siria',
#   'latitud': 36.714369,
#   'longitud': -4.428553,
#   'location': {'type': 'Point', 'coordinates': [36.714369, -4.428553]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de66'),
#   'nombre': 'Clasic Disco Club',
#   'latitud': 36.719222,
#   'longitud': -4.411931,
#   'location': {'type': 'Point', 'coordinates': [36.719222, -4.411931]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de22'),
#   'nombre': 'Empresas de reformas',
#   'latitud': 36.72103308699949,
#   'longitud': -4.410109519958496,
#   'location': {'type': 'Point',
#    'coordinates': [36.72103308699949, -4.410109519958496]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de48'),
#   'nombre': 'Málaga-Costa Del Sol Airport Aeropuerto De Málaga - Costa Del Sol',
#   'latitud': 36.71715,
#   'longitud': -4.433338,
#   'location': {'type': 'Point', 'coordinates': [36.71715, -4.433338]}},
#  {'_id': ObjectId('619017ebe231d949cbb2de47'),
#   'nombre': 'Taxi Malaga Airport',
#   'latitud': 36.722638576,
#   'longitud': -4.438587674,
#   'location': {'type': 'Point', 'coordinates': [36.722638576, -4.438587674]}}]

# %%
datos_MALAGA.sample()
# Out:
#            nombre    latitud  longitud  \
# 85  Discovery Bar  36.600977 -4.515824
#
#                                              location
# 85  {'type': 'Point', 'coordinates': [36.600977, -...

# %%
gdf_mlg = gpd.GeoDataFrame(datos_MALAGA, geometry=gpd.points_from_xy(datos_MALAGA.longitud, datos_MALAGA.latitud))

# %%
gdf_mlg.sample()
# Out:
#                            nombre    latitud  longitud  \
# 59  Estación Autobuses Aeropuerto  36.676709 -4.490991
#
#                                              location  \
# 59  {'type': 'Point', 'coordinates': [36.676709227...
#
#                      geometry
# 59  POINT (-4.49099 36.67671)

# %%
Map(Layer(gdf_mlg, "color:blue", popup_hover=[popup_element("nombre", "Sitios cerca de mi propuesta de ubicación en Málaga")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %% [markdown]
# #### C. Barcelona:

# %%
BARCELONA = db.get_collection("BARCELONA") # Me conecto a la colección "BARCELONA".

BARCELONA
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'PROYECTO_3'), 'BARCELONA')

# %%
db.BARCELONA.create_index([("location", GEOSPHERE)]) # Creo el index 2dsphere.
# Out:
# 'location_2dsphere'

# %%
metros= 2000 # radio máximo de búsqueda que establezco respecto a mis coordenadas.

# %%
query = {"location": {"$near": {"$geometry":{'type': 'Point', 'coordinates': [41.38781, 2.16920]}, "$maxDistance": metros}}}

query
# Out:
# {'location': {'$near': {'$geometry': {'type': 'Point',
#     'coordinates': [41.38781, 2.1692]},
#    '$maxDistance': 2000}}}

# %%
list(BARCELONA.find(query))
# Out:
# [{'_id': ObjectId('61901d15e231d949cbb2dedc'),
#   'nombre': 'Starbucks',
#   'latitud': 41.38784750930173,
#   'longitud': 2.1696339235092985,
#   'location': {'type': 'Point',
#    'coordinates': [41.38784750930173, 2.1696339235092985]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deec'),
#   'nombre': 'Dirty House Disco',
#   'latitud': 41.387745,
#   'longitud': 2.168554,
#   'location': {'type': 'Point', 'coordinates': [41.387745, 2.168554]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dece'),
#   'nombre': 'Starbucks Rambla Cataluña',
#   'latitud': 41.387953542832165,
#   'longitud': 2.1679005112034084,
#   'location': {'type': 'Point',
#    'coordinates': [41.387953542832165, 2.1679005112034084]}},
#  {'_id': ObjectId('61901d15e231d949cbb2decf'),
#   'nombre': 'Starbucks Pelai',
#   'latitud': 41.38580458944728,
#   'longitud': 2.1678578853607178,
#   'location': {'type': 'Point',
#    'coordinates': [41.38580458944728, 2.1678578853607178]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded2'),
#   'nombre': 'Starbucks Sant Pere',
#   'latitud': 41.38878261751958,
#   'longitud': 2.1720633907608704,
#   'location': {'type': 'Point',
#    'coordinates': [41.38878261751958, 2.1720633907608704]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def8'),
#   'nombre': 'Discos Revolver',
#   'latitud': 41.38472548742028,
#   'longitud': 2.1694385454340037,
#   'location': {'type': 'Point',
#    'coordinates': [41.38472548742028, 2.1694385454340037]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deee'),
#   'nombre': 'Disco Bus',
#   'latitud': 41.389916,
#   'longitud': 2.171634,
#   'location': {'type': 'Point', 'coordinates': [41.389916, 2.171634]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded5'),
#   'nombre': 'Starbucks',
#   'latitud': 41.384856,
#   'longitud': 2.170487,
#   'location': {'type': 'Point', 'coordinates': [41.384856, 2.170487]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deff'),
#   'nombre': 'Discos Tesla',
#   'latitud': 41.384682,
#   'longitud': 2.170254,
#   'location': {'type': 'Point', 'coordinates': [41.384682, 2.170254]}},
#  {'_id': ObjectId('61901d15e231d949cbb2defd'),
#   'nombre': 'Discos Impacto',
#   'latitud': 41.384933322351955,
#   'longitud': 2.167297937028547,
#   'location': {'type': 'Point',
#    'coordinates': [41.384933322351955, 2.167297937028547]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de94'),
#   'nombre': 'Mercado Condal de Diseño',
#   'latitud': 41.3902551,
#   'longitud': 2.1719942,
#   'location': {'type': 'Point', 'coordinates': [41.3902551, 2.1719942]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded1'),
#   'nombre': 'Starbucks Plaza Universitat',
#   'latitud': 41.38641765662956,
#   'longitud': 2.1651495862102075,
#   'location': {'type': 'Point',
#    'coordinates': [41.38641765662956, 2.1651495862102075]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded0'),
#   'nombre': 'Starbucks Rambla Canaletas',
#   'latitud': 41.38348531847921,
#   'longitud': 2.1713820474796326,
#   'location': {'type': 'Point',
#    'coordinates': [41.38348531847921, 2.1713820474796326]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def0'),
#   'nombre': 'Lux Disco',
#   'latitud': 41.39182292637865,
#   'longitud': 2.166363470318606,
#   'location': {'type': 'Point',
#    'coordinates': [41.39182292637865, 2.166363470318606]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df0b'),
#   'nombre': 'All Vegan',
#   'latitud': 41.38282,
#   'longitud': 2.169548,
#   'location': {'type': 'Point', 'coordinates': [41.38282, 2.169548]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded3'),
#   'nombre': 'Starbucks Consel',
#   'latitud': 41.39073404229646,
#   'longitud': 2.1651365170026944,
#   'location': {'type': 'Point',
#    'coordinates': [41.39073404229646, 2.1651365170026944]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de97'),
#   'nombre': 'Mesa de Diseño',
#   'latitud': 41.392668,
#   'longitud': 2.170899,
#   'location': {'type': 'Point', 'coordinates': [41.392668, 2.170899]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de92'),
#   'nombre': 'Tuctucbarcelona —Diseño Gráfico y Web—',
#   'latitud': 41.38627347557645,
#   'longitud': 2.1741852164268494,
#   'location': {'type': 'Point',
#    'coordinates': [41.38627347557645, 2.1741852164268494]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df01'),
#   'nombre': 'Discover Underwear Store Portaferrissa',
#   'latitud': 41.38650806253766,
#   'longitud': 2.174650423500335,
#   'location': {'type': 'Point',
#    'coordinates': [41.38650806253766, 2.174650423500335]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de96'),
#   'nombre': 'RC2 Ingenieria y Diseño, S.L',
#   'latitud': 41.39063818034419,
#   'longitud': 2.1743059158325195,
#   'location': {'type': 'Point',
#    'coordinates': [41.39063818034419, 2.1743059158325195]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deb1'),
#   'nombre': 'Tren Aeroport - Airport Train',
#   'latitud': 41.39279993494302,
#   'longitud': 2.1658932662641543,
#   'location': {'type': 'Point',
#    'coordinates': [41.39279993494302, 2.1658932662641543]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dedb'),
#   'nombre': 'Starbucks Room Mate Anna',
#   'latitud': 41.39278181321591,
#   'longitud': 2.1656320100589097,
#   'location': {'type': 'Point',
#    'coordinates': [41.39278181321591, 2.1656320100589097]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df1c'),
#   'nombre': 'Falafel Vegano - de Shani',
#   'latitud': 41.381904,
#   'longitud': 2.171337,
#   'location': {'type': 'Point', 'coordinates': [41.381904, 2.171337]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deed'),
#   'nombre': 'Discos Paradiso',
#   'latitud': 41.38222323239239,
#   'longitud': 2.165922262785513,
#   'location': {'type': 'Point',
#    'coordinates': [41.38222323239239, 2.165922262785513]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded8'),
#   'nombre': 'Starbucks Plaza Universitat',
#   'latitud': 41.38541870874625,
#   'longitud': 2.163150288025445,
#   'location': {'type': 'Point',
#    'coordinates': [41.38541870874625, 2.163150288025445]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dee2'),
#   'nombre': 'Starbucks',
#   'latitud': 41.38190998967705,
#   'longitud': 2.172113994974859,
#   'location': {'type': 'Point',
#    'coordinates': [41.38190998967705, 2.172113994974859]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df15'),
#   'nombre': 'Veganoteca',
#   'latitud': 41.38280383231907,
#   'longitud': 2.1643617866825533,
#   'location': {'type': 'Point',
#    'coordinates': [41.38280383231907, 2.1643617866825533]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df02'),
#   'nombre': 'Discos Juandó',
#   'latitud': 41.381552132684774,
#   'longitud': 2.165581398938492,
#   'location': {'type': 'Point',
#    'coordinates': [41.381552132684774, 2.165581398938492]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df05'),
#   'nombre': 'Discosduros.eu',
#   'latitud': 41.38383507728577,
#   'longitud': 2.1631425619125366,
#   'location': {'type': 'Point',
#    'coordinates': [41.38383507728577, 2.1631425619125366]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df0c'),
#   'nombre': 'Cuco Vegan Fashion',
#   'latitud': 41.38232,
#   'longitud': 2.1739783,
#   'location': {'type': 'Point', 'coordinates': [41.38232, 2.1739783]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def3'),
#   'nombre': 'Athletic Disco Club',
#   'latitud': 41.380393,
#   'longitud': 2.170293,
#   'location': {'type': 'Point', 'coordinates': [41.380393, 2.170293]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de95'),
#   'nombre': 'Diseño Paginas Web Yá Barcelona',
#   'latitud': 41.380311,
#   'longitud': 2.169969,
#   'location': {'type': 'Point', 'coordinates': [41.380311, 2.169969]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df04'),
#   'nombre': "Discos Edison's",
#   'latitud': 41.3802615245337,
#   'longitud': 2.168244335673664,
#   'location': {'type': 'Point',
#    'coordinates': [41.3802615245337, 2.168244335673664]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df08'),
#   'nombre': "Discos Edison's",
#   'latitud': 41.3802289,
#   'longitud': 2.1683691,
#   'location': {'type': 'Point', 'coordinates': [41.3802289, 2.1683691]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df07'),
#   'nombre': 'Discoteca TURMIX',
#   'latitud': 41.385281,
#   'longitud': 2.1766569999999774,
#   'location': {'type': 'Point',
#    'coordinates': [41.385281, 2.1766569999999774]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dee4'),
#   'nombre': 'Starbucks',
#   'latitud': 41.39459,
#   'longitud': 2.164942,
#   'location': {'type': 'Point', 'coordinates': [41.39459, 2.164942]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df18'),
#   'nombre': 'Tulsi Vegana',
#   'latitud': 41.38782,
#   'longitud': 2.1611705,
#   'location': {'type': 'Point', 'coordinates': [41.38782, 2.1611705]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded4'),
#   'nombre': 'Starbucks Vía Laietana',
#   'latitud': 41.385212881187684,
#   'longitud': 2.177009738540203,
#   'location': {'type': 'Point',
#    'coordinates': [41.385212881187684, 2.177009738540203]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de9a'),
#   'nombre': 'Red. Asociación De Diseño',
#   'latitud': 41.396337,
#   'longitud': 2.167923,
#   'location': {'type': 'Point', 'coordinates': [41.396337, 2.167923]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def4'),
#   'nombre': 'Shiny Disco Balls',
#   'latitud': 41.395878,
#   'longitud': 2.165344,
#   'location': {'type': 'Point', 'coordinates': [41.395878, 2.165344]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df06'),
#   'nombre': 'Discomóvil',
#   'latitud': 41.39039671055913,
#   'longitud': 2.1603047847747803,
#   'location': {'type': 'Point',
#    'coordinates': [41.39039671055913, 2.1603047847747803]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de98'),
#   'nombre': 'Dulce Diseño El Born',
#   'latitud': 41.38811880145053,
#   'longitud': 2.1785008907318115,
#   'location': {'type': 'Point',
#    'coordinates': [41.38811880145053, 2.1785008907318115]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df1f'),
#   'nombre': 'Fira Vegana Pou De La Figuera',
#   'latitud': 41.38821,
#   'longitud': 2.1787486,
#   'location': {'type': 'Point', 'coordinates': [41.38821, 2.1787486]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df16'),
#   'nombre': 'vegania',
#   'latitud': 41.38197043409701,
#   'longitud': 2.1772035155317075,
#   'location': {'type': 'Point',
#    'coordinates': [41.38197043409701, 2.1772035155317075]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df21'),
#   'nombre': 'Lujuria Vegana',
#   'latitud': 41.37815,
#   'longitud': 2.173195,
#   'location': {'type': 'Point', 'coordinates': [41.37815, 2.173195]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df09'),
#   'nombre': 'Discoteca Twin',
#   'latitud': 41.38086,
#   'longitud': 2.1774106,
#   'location': {'type': 'Point', 'coordinates': [41.38086, 2.1774106]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df1e'),
#   'nombre': 'Fira vegana',
#   'latitud': 41.38601320303864,
#   'longitud': 2.1798863377461486,
#   'location': {'type': 'Point',
#    'coordinates': [41.38601320303864, 2.1798863377461486]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def2'),
#   'nombre': 'Disco Taxi',
#   'latitud': 41.391142,
#   'longitud': 2.179841,
#   'location': {'type': 'Point', 'coordinates': [41.391142, 2.179841]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df17'),
#   'nombre': 'Veganoteca',
#   'latitud': 41.38263422336413,
#   'longitud': 2.159306128218218,
#   'location': {'type': 'Point',
#    'coordinates': [41.38263422336413, 2.159306128218218]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df1d'),
#   'nombre': 'EnjoyVegan',
#   'latitud': 41.38814481227262,
#   'longitud': 2.180385485092679,
#   'location': {'type': 'Point',
#    'coordinates': [41.38814481227262, 2.180385485092679]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df0d'),
#   'nombre': 'ENJOY VEGAN',
#   'latitud': 41.3881518,
#   'longitud': 2.18067259999998,
#   'location': {'type': 'Point',
#    'coordinates': [41.3881518, 2.18067259999998]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def1'),
#   'nombre': 'Discoteca Hotel Omm',
#   'latitud': 41.39614297786824,
#   'longitud': 2.1609368998046974,
#   'location': {'type': 'Point',
#    'coordinates': [41.39614297786824, 2.1609368998046974]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df0a'),
#   'nombre': 'Vegan Junk Food Bar',
#   'latitud': 41.38338564677454,
#   'longitud': 2.1802550554275513,
#   'location': {'type': 'Point',
#    'coordinates': [41.38338564677454, 2.1802550554275513]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de9c'),
#   'nombre': 'Ofita Diseño',
#   'latitud': 41.396945320457235,
#   'longitud': 2.160990002536531,
#   'location': {'type': 'Point',
#    'coordinates': [41.396945320457235, 2.160990002536531]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deb4'),
#   'nombre': 'Taxi richting Barcelona airport',
#   'latitud': 41.376675,
#   'longitud': 2.174543,
#   'location': {'type': 'Point', 'coordinates': [41.376675, 2.174543]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deb3'),
#   'nombre': 'Taxi richting barcelona airport',
#   'latitud': 41.376711,
#   'longitud': 2.174903,
#   'location': {'type': 'Point', 'coordinates': [41.376711, 2.174903]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df0f'),
#   'nombre': 'Monchito Vegan',
#   'latitud': 41.38103,
#   'longitud': 2.179852,
#   'location': {'type': 'Point', 'coordinates': [41.38103, 2.179852]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded6'),
#   'nombre': 'Starbucks Argentería',
#   'latitud': 41.38356136455636,
#   'longitud': 2.181132782745855,
#   'location': {'type': 'Point',
#    'coordinates': [41.38356136455636, 2.181132782745855]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df10'),
#   'nombre': 'Monchito Vegan',
#   'latitud': 41.380970639204,
#   'longitud': 2.1798795461654663,
#   'location': {'type': 'Point',
#    'coordinates': [41.380970639204, 2.1798795461654663]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df0e'),
#   'nombre': 'Nae Vegan Shoes',
#   'latitud': 41.383823,
#   'longitud': 2.1817176,
#   'location': {'type': 'Point', 'coordinates': [41.383823, 2.1817176]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dedf'),
#   'nombre': 'Starbucks',
#   'latitud': 41.395066280471816,
#   'longitud': 2.15812165819131,
#   'location': {'type': 'Point',
#    'coordinates': [41.395066280471816, 2.15812165819131]}},
#  {'_id': ObjectId('61901d15e231d949cbb2deb2'),
#   'nombre': 'Burcelona bus to Girona Airport',
#   'latitud': 41.3813237479011,
#   'longitud': 2.181407794519846,
#   'location': {'type': 'Point',
#    'coordinates': [41.3813237479011, 2.181407794519846]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df19'),
#   'nombre': 'Tamaka Barcelona Eixample',
#   'latitud': 41.38962,
#   'longitud': 2.1552452,
#   'location': {'type': 'Point', 'coordinates': [41.38962, 2.1552452]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de9d'),
#   'nombre': 'Zapatos de Diseño',
#   'latitud': 41.38336954702104,
#   'longitud': 2.1825993061065674,
#   'location': {'type': 'Point',
#    'coordinates': [41.38336954702104, 2.1825993061065674]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df1b'),
#   'nombre': 'Veganashi',
#   'latitud': 41.37267,
#   'longitud': 2.1687887,
#   'location': {'type': 'Point', 'coordinates': [41.37267, 2.1687887]}},
#  {'_id': ObjectId('61901d15e231d949cbb2ded9'),
#   'nombre': 'Starbucks',
#   'latitud': 41.4023121744117,
#   'longitud': 2.173994779586792,
#   'location': {'type': 'Point',
#    'coordinates': [41.4023121744117, 2.173994779586792]}},
#  {'_id': ObjectId('61901d15e231d949cbb2def9'),
#   'nombre': 'Pisco Disco',
#   'latitud': 41.372001,
#   'longitud': 2.165844,
#   'location': {'type': 'Point', 'coordinates': [41.372001, 2.165844]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dea3'),
#   'nombre': 'Modo. Arquitectura y Diseño',
#   'latitud': 41.400688,
#   'longitud': 2.157411,
#   'location': {'type': 'Point', 'coordinates': [41.400688, 2.157411]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dea1'),
#   'nombre': 'Aktiva - Agencia de diseño',
#   'latitud': 41.38036,
#   'longitud': 2.153139,
#   'location': {'type': 'Point', 'coordinates': [41.38036, 2.153139]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df26'),
#   'nombre': '2Y Restaurante Vegano y macrobiotico',
#   'latitud': 41.3883039348524,
#   'longitud': 2.1514320373535156,
#   'location': {'type': 'Point',
#    'coordinates': [41.3883039348524, 2.1514320373535156]}},
#  {'_id': ObjectId('61901d15e231d949cbb2de9e'),
#   'nombre': 'Dulce Diseño Vila de Gràcia',
#   'latitud': 41.40220353263401,
#   'longitud': 2.1587061882019043,
#   'location': {'type': 'Point',
#    'coordinates': [41.40220353263401, 2.1587061882019043]}},
#  {'_id': ObjectId('61901d15e231d949cbb2df24'),
#   'nombre': '2Y Cuina Vegana, Energética y Macrobiòtica',
#   'latitud': 41.38831,
#   'longitud': 2.151386,
#   'location': {'type': 'Point', 'coordinates': [41.38831, 2.151386]}},
#  {'_id': ObjectId('61901d15e231d949cbb2dea0'),
#   'nombre': 'dulce diseño',
#   'latitud': 41.402268,
#   'longitud': 2.158632,
#   'location': {'type': 'Point', 'coordinates': [41.402268, 2.158632]}}]

# %%
datos_BARCELONA.sample()
# Out:
#                               nombre   latitud  longitud  \
# 130  Vegan Streets Barcelona Glories  41.41004  2.193974
#
#                                               location
# 130  {'type': 'Point', 'coordinates': [41.4100395, ...

# %%
gdf_bcn = gpd.GeoDataFrame(datos_BARCELONA, geometry=gpd.points_from_xy(datos_BARCELONA.longitud, datos_BARCELONA.latitud))

gdf_bcn.sample()
# Out:
#                     nombre    latitud  longitud  \
# 75  Starbucks Diagonal 640  41.391069   2.13641
#
#                                              location  \
# 75  {'type': 'Point', 'coordinates': [41.391069270...
#
#                     geometry
# 75  POINT (2.13641 41.39107)

# %%
Map(Layer(gdf_bcn, "color:pink", popup_hover=[popup_element("nombre", "Sitios cerca de mi propuesta de ubicación en Barcelona")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]
